# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from src.data.loader import load_raw_data, validate_schema\n",
    "from src.data.preprocessor import encode_features, split_data, save_processed\n",
    "from pathlib import Path\n",
    "\n",
    "# Load raw data\n",
    "df = load_raw_data(Path('data/raw/leads.csv'))\n",
    "validate_schema(df)\n",
    "print(\"Schema validation passed.\\n\")\n",
    "print(\"Before preprocessing:\")\n",
    "print(df.head())"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Encode and scale\n",
    "df_processed, encoders = encode_features(df)\n",
    "print(\"After preprocessing (encoded & scaled):\")\n",
    "print(df_processed.head())"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Split data\n",
    "X_train, X_test, y_train, y_test, label_encoder = split_data(df_processed, target_col='label')\n",
    "print(f\"X_train shape: {X_train.shape}, X_test shape: {X_test.shape}\")\n",
    "print(f\"y_train unique: {set(y_train)}, y_test unique: {set(y_test)}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Save processed data\n",
    "save_processed(df_processed, Path('data/processed/leads_processed.csv'))\n",
    "print(\"Processed data saved to data/processed/leads_processed.csv\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
