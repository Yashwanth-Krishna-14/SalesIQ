# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import mlflow\n",
    "import pandas as pd\n",
    "\n",
    "mlflow.set_tracking_uri(\"./mlflow/mlruns\")\n",
    "\n",
    "# List all runs\n",
    "experiment = mlflow.get_experiment_by_name(\"SalesIQ\")\n",
    "if experiment:\n",
    "    runs = mlflow.search_runs(experiment_ids=[experiment.experiment_id])\n",
    "    print(\"All runs:\")\n",
    "    print(runs[['run_id', 'tags.mlflow.runName', 'metrics.accuracy', 'metrics.f1', 'metrics.auc']])\n",
    "else:\n",
    "    print(\"No SalesIQ experiment found.\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Compare RF vs XGBoost\n",
    "if experiment:\n",
    "    runs_df = mlflow.search_runs(experiment_ids=[experiment.experiment_id])\n",
    "    # Filter by run name\n",
    "    rf = runs_df[runs_df['tags.mlflow.runName'] == 'RandomForest_100']\n",
    "    xgb = runs_df[runs_df['tags.mlflow.runName'] == 'XGBoost_100']\n",
    "    comparison = pd.DataFrame({\n",
    "        'Metric': ['accuracy', 'f1', 'precision', 'recall', 'auc'],\n",
    "        'Random Forest': rf[['metrics.accuracy','metrics.f1','metrics.precision','metrics.recall','metrics.auc']].iloc[0].values,\n",
    "        'XGBoost': xgb[['metrics.accuracy','metrics.f1','metrics.precision','metrics.recall','metrics.auc']].iloc[0].values\n",
    "    })\n",
    "    print(\"Model Comparison:\")\n",
    "    print(comparison)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Best model recommendation\n",
    "if experiment:\n",
    "    best_run = mlflow.search_runs(experiment_ids=[experiment.experiment_id], order_by=['metrics.accuracy DESC'], max_results=1)\n",
    "    best_name = best_run['tags.mlflow.runName'].iloc[0]\n",
    "    best_acc = best_run['metrics.accuracy'].iloc[0]\n",
    "    print(f\"🏆 Best model: {best_name} with accuracy {best_acc:.4f}\")"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
